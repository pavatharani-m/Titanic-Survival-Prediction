# %%
DATA SCIENCE INTERN @BHARAT INTERN
AUTHOR : Jaggavarapu Srikanth Reddy
TASK 1 : STOCK PREDICTION
PURPOSE : TO PREDICT THE STOCK PRICE OF A COMPANY USING LSTM.
ABOUT DATASET
Google Stock Prediction
This dataset contains historical data of Google's stock prices and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.

The columns in the dataset are as follows:

Symbol: The name of the company, which is GOOG in this case.
Date: The year and date of the stock data.
Close: The closing price of Google's stock on a particular day.
High: The highest value reached by Google's stock on the given day.
Low: The lowest value reached by Google's stock on the given day.
Open: The opening value of Google's stock on the given day.
Volume: The trading volume of Google's stock on the given day, i.e., the number of shares traded.
adjClose: The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
adjHigh: The adjusted highest value reached by Google's stock on the given day.
adjLow: The adjusted lowest value reached by Google's stock on the given day.
adjOpen: The adjusted opening value of Google's stock on the given day.
adjVolume: The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
divCash: The amount of cash dividend paid out to shareholders on the given day.
splitFactor: The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.
The dataset is available at Kaggle : https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction







STEPS INVOLVED :
1 . IMPORTING LIBRARIES AND DATA TO BE USED
2. GATHERING INSIGHTS
3. DATA PRE-PROCESSING
4. CREATING LSTM MODEL
5. VISUALIZING ACTUAL VS PREDICTED DATA

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/Google_Stocks_dataset.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 97ms/step - loss: 0.0059 - mean_absolute_error: 0.0541 - val_loss: 0.0109 - val_mean_absolute_error: 0.0841
# Epoch 2/100
# 28/28 [==============================] - 2s 55ms/step - loss: 6.7578e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0039 - val_mean_absolute_error: 0.0484
# Epoch 3/100
# 28/28 [==============================] - 2s 63ms/step - loss: 4.1676e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0028 - val_mean_absolute_error: 0.0409
# Epoch 4/100
# 28/28 [==============================] - 3s 92ms/step - loss: 3.9487e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 5/100
# 28/28 [==============================] - 2s 78ms/step - loss: 3.8967e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0030 - val_mean_absolute_error: 0.0415
# Epoch 6/100
# 28/28 [==============================] - 2s 75ms/step - loss: 3.9038e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0036 - val_mean_absolute_error: 0.0472
# Epoch 7/100
# 28/28 [==============================] - 2s 56ms/step - loss: 4.0119e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0034 - val_mean_absolute_error: 0.0450
# Epoch 8/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.6874e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0035 - val_mean_absolute_error: 0.0467
# Epoch 9/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.6498e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0032 - val_mean_absolute_error: 0.0441
# Epoch 10/100
# 28/28 [==============================] - 2s 74ms/step - loss: 3.4335e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 11/100
# 28/28 [==============================] - 2s 82ms/step - loss: 3.4148e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0030 - val_mean_absolute_error: 0.0421
# Epoch 12/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.3214e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382
# Epoch 13/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.5695e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0039 - val_mean_absolute_error: 0.0488
# Epoch 14/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.4245e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 15/100
# 28/28 [==============================] - 1s 52ms/step - loss: 3.3325e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0055 - val_mean_absolute_error: 0.0605
# Epoch 16/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.9626e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0051 - val_mean_absolute_error: 0.0568
# Epoch 17/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.1459e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0031 - val_mean_absolute_error: 0.0416
# Epoch 18/100
# 28/28 [==============================] - 2s 88ms/step - loss: 3.0581e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0034 - val_mean_absolute_error: 0.0447
# Epoch 19/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.6857e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0050 - val_mean_absolute_error: 0.0555
# Epoch 20/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.7263e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0028 - val_mean_absolute_error: 0.0391
# Epoch 21/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.9039e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0051 - val_mean_absolute_error: 0.0575
# Epoch 22/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.0410e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0025 - val_mean_absolute_error: 0.0369
# Epoch 23/100
# 28/28 [==============================] - 1s 54ms/step - loss: 3.0157e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0056 - val_mean_absolute_error: 0.0589
# Epoch 24/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.5768e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0048 - val_mean_absolute_error: 0.0545
# Epoch 25/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.6761e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 26/100
# 28/28 [==============================] - 3s 95ms/step - loss: 2.6651e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0035 - val_mean_absolute_error: 0.0448
# Epoch 27/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.5056e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0041 - val_mean_absolute_error: 0.0495
# Epoch 28/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.8743e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0031 - val_mean_absolute_error: 0.0420
# Epoch 29/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.8314e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0054 - val_mean_absolute_error: 0.0600
# Epoch 30/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.5237e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0043 - val_mean_absolute_error: 0.0512
# Epoch 31/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.4949e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0037 - val_mean_absolute_error: 0.0460
# Epoch 32/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.4254e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0035 - val_mean_absolute_error: 0.0437
# Epoch 33/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.3261e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0043 - val_mean_absolute_error: 0.0495
# Epoch 34/100
# 28/28 [==============================] - 2s 81ms/step - loss: 2.3341e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0042 - val_mean_absolute_error: 0.0499
# Epoch 35/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.3132e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 36/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.1192e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0046 - val_mean_absolute_error: 0.0541
# Epoch 37/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3740e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0041 - val_mean_absolute_error: 0.0509
# Epoch 38/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.2194e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0039 - val_mean_absolute_error: 0.0483
# Epoch 39/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3770e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 40/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.6218e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0027 - val_mean_absolute_error: 0.0382
# Epoch 41/100
# 28/28 [==============================] - 2s 87ms/step - loss: 2.6734e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0061 - val_mean_absolute_error: 0.0654
# Epoch 42/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.2126e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 43/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.1636e-04 - mean_absolute_error: 0.0107 - val_loss: 8.9183e-04 - val_mean_absolute_error: 0.0221
# Epoch 44/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.1695e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0031 - val_mean_absolute_error: 0.0424
# Epoch 45/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.1036e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0049 - val_mean_absolute_error: 0.0563
# Epoch 46/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.8332e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 47/100
# 28/28 [==============================] - 2s 73ms/step - loss: 2.0612e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
# Epoch 48/100
# 28/28 [==============================] - 3s 101ms/step - loss: 1.8662e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0024 - val_mean_absolute_error: 0.0375
# Epoch 49/100
# 28/28 [==============================] - 3s 117ms/step - loss: 1.9083e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0020 - val_mean_absolute_error: 0.0328
# Epoch 50/100
# 28/28 [==============================] - 4s 138ms/step - loss: 1.9150e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0022 - val_mean_absolute_error: 0.0344
# Epoch 51/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8114e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0026 - val_mean_absolute_error: 0.0385
# Epoch 52/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.7202e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0045 - val_mean_absolute_error: 0.0540
# Epoch 53/100
# 28/28 [==============================] - 2s 84ms/step - loss: 1.8954e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 54/100
# 28/28 [==============================] - 3s 108ms/step - loss: 1.8894e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0025 - val_mean_absolute_error: 0.0385
# Epoch 55/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.7643e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0018 - val_mean_absolute_error: 0.0312
# Epoch 56/100
# 28/28 [==============================] - 3s 115ms/step - loss: 1.8651e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 57/100
# 28/28 [==============================] - 4s 146ms/step - loss: 2.1019e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0040 - val_mean_absolute_error: 0.0513
# Epoch 58/100
# 28/28 [==============================] - 3s 121ms/step - loss: 2.0032e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0022 - val_mean_absolute_error: 0.0374
# Epoch 59/100
# 28/28 [==============================] - 3s 120ms/step - loss: 1.6470e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0016 - val_mean_absolute_error: 0.0302
# Epoch 60/100
# 28/28 [==============================] - 3s 122ms/step - loss: 1.7500e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0022 - val_mean_absolute_error: 0.0370
# Epoch 61/100
# 28/28 [==============================] - 4s 140ms/step - loss: 1.8221e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0028 - val_mean_absolute_error: 0.0418
# Epoch 62/100
# 28/28 [==============================] - 3s 125ms/step - loss: 1.6972e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0020 - val_mean_absolute_error: 0.0330
# Epoch 63/100
# 28/28 [==============================] - 4s 148ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 64/100
# 28/28 [==============================] - 4s 156ms/step - loss: 1.6317e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0018 - val_mean_absolute_error: 0.0316
# Epoch 65/100
# 28/28 [==============================] - 4s 131ms/step - loss: 1.5775e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 66/100
# 28/28 [==============================] - 3s 117ms/step - loss: 1.5331e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0020 - val_mean_absolute_error: 0.0351
# Epoch 67/100
# 28/28 [==============================] - 3s 109ms/step - loss: 1.5251e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0026 - val_mean_absolute_error: 0.0401
# Epoch 68/100
# 28/28 [==============================] - 3s 89ms/step - loss: 1.6396e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0034 - val_mean_absolute_error: 0.0480
# Epoch 69/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.6360e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0018 - val_mean_absolute_error: 0.0319
# Epoch 70/100
# 28/28 [==============================] - 2s 89ms/step - loss: 1.6728e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0047 - val_mean_absolute_error: 0.0573
# Epoch 71/100
# 28/28 [==============================] - 3s 103ms/step - loss: 1.5332e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0023 - val_mean_absolute_error: 0.0380
# Epoch 72/100
# 28/28 [==============================] - 3s 98ms/step - loss: 1.4367e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0018 - val_mean_absolute_error: 0.0322
# Epoch 73/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4704e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 74/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.5865e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 75/100
# 28/28 [==============================] - 3s 114ms/step - loss: 1.4373e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 76/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.4613e-04 - mean_absolute_error: 0.0087 - val_loss: 8.7029e-04 - val_mean_absolute_error: 0.0217
# Epoch 77/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3446e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 78/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.3915e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0014 - val_mean_absolute_error: 0.0286
# Epoch 79/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3486e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278
# Epoch 80/100
# 28/28 [==============================] - 4s 149ms/step - loss: 1.3712e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 81/100
# 28/28 [==============================] - 3s 113ms/step - loss: 1.3929e-04 - mean_absolute_error: 0.0084 - val_loss: 8.6926e-04 - val_mean_absolute_error: 0.0217
# Epoch 82/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.3565e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 83/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2776e-04 - mean_absolute_error: 0.0080 - val_loss: 9.9457e-04 - val_mean_absolute_error: 0.0239
# Epoch 84/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2618e-04 - mean_absolute_error: 0.0080 - val_loss: 7.5420e-04 - val_mean_absolute_error: 0.0203
# Epoch 85/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2058e-04 - mean_absolute_error: 0.0078 - val_loss: 8.1545e-04 - val_mean_absolute_error: 0.0211
# Epoch 86/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.3454e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0024 - val_mean_absolute_error: 0.0406
# Epoch 87/100
# 28/28 [==============================] - 3s 118ms/step - loss: 1.7457e-04 - mean_absolute_error: 0.0098 - val_loss: 6.9920e-04 - val_mean_absolute_error: 0.0193
# Epoch 88/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2232e-04 - mean_absolute_error: 0.0079 - val_loss: 5.1420e-04 - val_mean_absolute_error: 0.0165
# Epoch 89/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2440e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 90/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.1595e-04 - mean_absolute_error: 0.0075 - val_loss: 6.8578e-04 - val_mean_absolute_error: 0.0194
# Epoch 91/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2648e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 92/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2892e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 93/100
# 28/28 [==============================] - 5s 160ms/step - loss: 1.2864e-04 - mean_absolute_error: 0.0081 - val_loss: 3.5986e-04 - val_mean_absolute_error: 0.0140
# Epoch 94/100
# 28/28 [==============================] - 3s 117ms/step - loss: 1.3296e-04 - mean_absolute_error: 0.0084 - val_loss: 4.3074e-04 - val_mean_absolute_error: 0.0152
# Epoch 95/100
# 28/28 [==============================] - 3s 122ms/step - loss: 1.3703e-04 - mean_absolute_error: 0.0085 - val_loss: 8.5301e-04 - val_mean_absolute_error: 0.0219
# Epoch 96/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.3304e-04 - mean_absolute_error: 0.0081 - val_loss: 5.0388e-04 - val_mean_absolute_error: 0.0166
# Epoch 97/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.1742e-04 - mean_absolute_error: 0.0078 - val_loss: 6.6498e-04 - val_mean_absolute_error: 0.0188
# Epoch 98/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.1974e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0012 - val_mean_absolute_error: 0.0263
# Epoch 99/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.1523e-04 - mean_absolute_error: 0.0076 - val_loss: 7.8911e-04 - val_mean_absolute_error: 0.0209
# Epoch 100/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.2322e-04 - mean_absolute_error: 0.0079 - val_loss: 4.4689e-04 - val_mean_absolute_error: 0.0154

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 15ms/step
# array([[0.41213757, 0.41382986],
#        [0.41100416, 0.41304463],
#        [0.4049736 , 0.40743667],
#        [0.40928766, 0.4109512 ],
#        [0.41334108, 0.41471446]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1435.0701, 1435.2275],
#        [1432.9688, 1433.7722],
#        [1421.7886, 1423.3787],
#        [1429.7865, 1429.8923],
#        [1437.3013, 1436.867 ]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1435.070068      1435.227539
# 2020-05-28  1396.86  1416.73     1432.968750      1433.772217
# 2020-05-29  1416.94  1428.92     1421.788574      1423.378662
# 2020-06-01  1418.39  1431.82     1429.786499      1429.892334
# 2020-06-02  1430.55  1439.22     1437.301270      1436.866943

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
#Thank you Bharath intern so much
